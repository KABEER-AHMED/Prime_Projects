# %%
print("Hello world")
# Out:
# Hello world

# %%
class Store():
    products = {}
    total_products = 0
    def __init__(self):
        print("Welcome to Saravana Stores")
        for i in Store.products: print (i)
    def add_product(self,name,price):
        Store.products[name] = price
        Store.total_products+=1
    @staticmethod
    def discounted_price(price, discount_percent):
        final_price = price - ((discount_percent*price)/100)
        print(final_price)
        
    # pretty useless function

# %%
Macbook = Store()
# Out:
# Welcome to Saravana Stores

# %%
Macbook.add_products("macbook air m1", 500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Macbook.add_products("macbook air m1", 500)
#
# AttributeError: 'Store' object has no attribute 'add_products'
